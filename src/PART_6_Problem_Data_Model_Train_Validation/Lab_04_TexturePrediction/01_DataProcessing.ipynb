# %% [markdown]
# ## Texture Prediction
# ## STEP 1 image preparation

# %% [markdown]
# -----
# ##### Author: NJ Namju Lee / nj.namju@gmail.com
# ###### * Linkedin - https://www.linkedin.com/in/nj-namju-lee-926b3252/    * Git - https://github.com/NamjuLee
#
# ###### * Web - http://www.njstudio.co.kr                                  * Lab - http://www.njslab.com/NJSLabCore/
#
# ###### * Video(English) - https://www.youtube.com/c/njnamjulee            * Writing(English) - https://medium.com/@nj-namju
#
# ###### * Video(Korean) - https://www.youtube.com/c/CodeforDesign          * Writing(Korean) - https://brunch.co.kr/@njnamju
# -----

# %%
import glob
import os
import PIL
import PIL.Image
import cv2

# %%
THE_PATH = "dataRaw/wall/" # the path
index = 4
path = glob.glob(THE_PATH + "*.*") # get all path for image
PIL.Image.open(str(path[index])) # print a sample
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=380x253 at 0x18AC96BBD30>

# %%
path # print the path
# Out:
# ['dataRaw/wall\\1 (1).jpg',
#  'dataRaw/wall\\1 (10).jpg',
#  'dataRaw/wall\\1 (11).jpg',
#  'dataRaw/wall\\1 (12).jpg',
#  'dataRaw/wall\\1 (13).jpg',
#  'dataRaw/wall\\1 (14).jpg',
#  'dataRaw/wall\\1 (15).jpg',
#  'dataRaw/wall\\1 (16).jpg',
#  'dataRaw/wall\\1 (17).jpg',
#  'dataRaw/wall\\1 (18).jpg',
#  'dataRaw/wall\\1 (19).jpg',
#  'dataRaw/wall\\1 (20).jpg',
#  'dataRaw/wall\\1 (21).jpg',
#  'dataRaw/wall\\1 (22).jpg',
#  'dataRaw/wall\\1 (23).jpg',
#  'dataRaw/wall\\1 (24).jpg',
#  'dataRaw/wall\\1 (25).jpg',
#  'dataRaw/wall\\1 (26).jpg',
#  'dataRaw/wall\\1 (27).jpg',
#  'dataRaw/wall\\1 (28).jpg',
#  'dataRaw/wall\\1 (29).jpg',
#  'dataRaw/wall\\1 (30).jpg',
#  'dataRaw/wall\\1 (31).jpg',
#  'dataRaw/wall\\1 (32).jpg',
#  'dataRaw/wall\\1 (33).jpg',
#  'dataRaw/wall\\1 (34).jpg',
#  'dataRaw/wall\\1 (35).jpg',
#  'dataRaw/wall\\1 (36).jpg',
#  'dataRaw/wall\\1 (37).jpg',
#  'dataRaw/wall\\1 (38).jpg',
#  'dataRaw/wall\\1 (39).jpg',
#  'dataRaw/wall\\1 (4).jpg',
#  'dataRaw/wall\\1 (40).jpg',
#  'dataRaw/wall\\1 (41).jpg',
#  'dataRaw/wall\\1 (42).jpg',
#  'dataRaw/wall\\1 (43).jpg',
#  'dataRaw/wall\\1 (44).jpg',
#  'dataRaw/wall\\1 (45).jpg',
#  'dataRaw/wall\\1 (46).jpg',
#  'dataRaw/wall\\1 (47).jpg',
#  'dataRaw/wall\\1 (48).jpg',
#  'dataRaw/wall\\1 (49).jpg',
#  'dataRaw/wall\\1 (50).jpg',
#  'dataRaw/wall\\1 (51).jpg',
#  'dataRaw/wall\\1 (52).jpg',
#  'dataRaw/wall\\1 (53).jpg',
#  'dataRaw/wall\\1 (54).jpg',
#  'dataRaw/wall\\1 (55).jpg',
#  'dataRaw/wall\\1 (56).jpg',
#  'dataRaw/wall\\1 (57).jpg',
#  'dataRaw/wall\\1 (58).jpg',
#  'dataRaw/wall\\1 (59).jpg',
#  'dataRaw/wall\\1 (6).jpg',
#  'dataRaw/wall\\1 (60).jpg',
#  'dataRaw/wall\\1 (61).jpg',
#  'dataRaw/wall\\1 (62).jpg',
#  'dataRaw/wall\\1 (63).jpg',
#  'dataRaw/wall\\1 (64).jpg',
#  'dataRaw/wall\\1 (65).jpg',
#  'dataRaw/wall\\1 (66).jpg',
#  'dataRaw/wall\\1 (67).jpg',
#  'dataRaw/wall\\1 (68).jpg',
#  'dataRaw/wall\\1 (69).jpg',
#  'dataRaw/wall\\1 (7).jpg',
#  'dataRaw/wall\\1 (70).jpg',
#  'dataRaw/wall\\1 (71).jpg',
#  'dataRaw/wall\\1 (72).jpg',
#  'dataRaw/wall\\1 (73).jpg',
#  'dataRaw/wall\\1 (74).jpg',
#  'dataRaw/wall\\1 (75).jpg',
#  'dataRaw/wall\\1 (76).jpg',
#  'dataRaw/wall\\1 (77).jpg',
#  'dataRaw/wall\\1 (78).jpg',
#  'dataRaw/wall\\1 (79).jpg',
#  'dataRaw/wall\\1 (8).jpg',
#  'dataRaw/wall\\1 (80).jpg',
#  'dataRaw/wall\\1 (81).jpg',
#  'dataRaw/wall\\1 (82).jpg',
#  'dataRaw/wall\\1 (83).jpg',
#  'dataRaw/wall\\1 (84).jpg',
#  'dataRaw/wall\\1 (85).jpg',
#  'dataRaw/wall\\1 (86).jpg',
#  'dataRaw/wall\\1 (87).jpg',
#  'dataRaw/wall\\1 (9).jpg']

# %%
PATH_SAVED = 'dataRaw'
DIM = (100, 100) # new dimension of the images for traning

index = index 
im = PIL.Image.open(path[index]) # load the image by the index
 
width, height = im.size
size = 200

# setting the position for cropped image
left = width * 0.5 - size * 0.5
top = height * 0.5 - size * 0.5
right = width * 0.5 + size * 0.5
bottom = height * 0.5 + size * 0.5

# Cropping image of above dimension (it will not change original image)
im1 = im.crop((left, top, right, bottom))
im1 = im1.resize(DIM) # resize the cropped image
# im1.save(PATH_SAVED + "/img.png")
im1
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x18ACFE3D5E0>

# %%
# make the code above cell a function 
def imageProcess(path, size = 450, dim = 450):
    im = PIL.Image.open(path)
    width, height = im.size
    
    left = width * 0.5 - size * 0.5
    top = height * 0.5 - size * 0.5
    right = width * 0.5 + size * 0.5
    bottom = height * 0.5 + size * 0.5

    im1 = im.crop((left, top, right, bottom))
    im1 = im1.resize(dim)
    return im1

# %%
THE_PATH = "dataRaw/"
PATH_SAVED = "dataProcessed/"
allPath = [x[0] for x in os.walk(THE_PATH)]

SIZE = 200
DIM = (100, 100)

for path in allPath:
    if len(path) > 0:
        className = path.split('/')[1]
        files = glob.glob(path + "/*.*")
        if len(files) > 0:
            print(len(files))
            for j in range(len(files)):
                # className = path.split('/')[1]
                print(files[j])
                img = imageProcess(files[j], SIZE, DIM)
                # img.show()
                img.save(PATH_SAVED + str(className) + "_" + str(j) + ".jpg")
                # print(className)
                # break
        # break
# Out:
# 58
# dataRaw/brick\1 (10).jpg
# dataRaw/brick\1 (11).jpg
# dataRaw/brick\1 (12).jpg
# dataRaw/brick\1 (13).jpg
# dataRaw/brick\1 (14).jpg
# dataRaw/brick\1 (15).jpg
# dataRaw/brick\1 (16).jpg
# dataRaw/brick\1 (17).jpg
# dataRaw/brick\1 (18).jpg
# dataRaw/brick\1 (19).jpg
# dataRaw/brick\1 (2).jpg
# dataRaw/brick\1 (20).jpg
# dataRaw/brick\1 (21).jpg
# dataRaw/brick\1 (22).jpg
# dataRaw/brick\1 (23).jpg
# dataRaw/brick\1 (24).jpg
# dataRaw/brick\1 (25).jpg
# dataRaw/brick\1 (26).jpg
# dataRaw/brick\1 (27).jpg
# dataRaw/brick\1 (28).jpg
# dataRaw/brick\1 (29).jpg
# dataRaw/brick\1 (3).jpg
# dataRaw/brick\1 (30).jpg
# dataRaw/brick\1 (31).jpg
# dataRaw/brick\1 (32).jpg
# dataRaw/brick\1 (33).jpg
# dataRaw/brick\1 (34).jpg
# dataRaw/brick\1 (35).jpg
# dataRaw/brick\1 (36).jpg
# dataRaw/brick\1 (37).jpg
# dataRaw/brick\1 (38).jpg
# dataRaw/brick\1 (39).jpg
# dataRaw/brick\1 (4).jpg
# dataRaw/brick\1 (40).jpg
# dataRaw/brick\1 (41).jpg
# dataRaw/brick\1 (42).jpg
# dataRaw/brick\1 (43).jpg
# dataRaw/brick\1 (44).jpg
# dataRaw/brick\1 (45).jpg
# dataRaw/brick\1 (46).jpg
# dataRaw/brick\1 (47).jpg
# dataRaw/brick\1 (49).jpg
# dataRaw/brick\1 (5).jpg
# dataRaw/brick\1 (50).jpg
# dataRaw/brick\1 (51).jpg
# dataRaw/brick\1 (52).jpg
# dataRaw/brick\1 (53).jpg
# dataRaw/brick\1 (54).jpg
# dataRaw/brick\1 (55).jpg
# dataRaw/brick\1 (56).jpg
# dataRaw/brick\1 (57).jpg
# dataRaw/brick\1 (58).jpg
# dataRaw/brick\1 (59).jpg
# dataRaw/brick\1 (6).jpg
# dataRaw/brick\1 (60).jpg
# dataRaw/brick\1 (7).jpg
# dataRaw/brick\1 (8).jpg
# dataRaw/brick\1 (9).jpg
# 46
# dataRaw/concrete\1 (1).jpg
# dataRaw/concrete\1 (37).jpg
# dataRaw/concrete\1 (43).JPG
# dataRaw/concrete\1 (44).jpg
# dataRaw/concrete\1 (45).jpg
# dataRaw/concrete\1 (46).jpg
# dataRaw/concrete\1 (47).JPG
# dataRaw/concrete\1 (48).JPG
# dataRaw/concrete\1 (49).JPG
# dataRaw/concrete\1 (50).JPG
# dataRaw/concrete\1 (51).JPG
# dataRaw/concrete\1 (52).jpg
# dataRaw/concrete\1 (53).JPG
# dataRaw/concrete\1 (54).JPG
# dataRaw/concrete\1 (55).jpg
# dataRaw/concrete\1 (56).jpg
# dataRaw/concrete\1 (57).JPG
# dataRaw/concrete\1 (58).JPG
# dataRaw/concrete\1 (59).JPG
# dataRaw/concrete\1 (60).JPG
# dataRaw/concrete\1 (61).JPG
# dataRaw/concrete\1 (62).JPG
# dataRaw/concrete\1 (63).JPG
# dataRaw/concrete\1 (64).JPG
# dataRaw/concrete\1 (65).jpg
# dataRaw/concrete\1 (66).JPG
# dataRaw/concrete\1 (67).jpg
# dataRaw/concrete\1 (68).jpg
# dataRaw/concrete\1 (69).jpg
# dataRaw/concrete\1 (70).jpg
# dataRaw/concrete\1 (71).jpg
# dataRaw/concrete\1 (72).JPG
# dataRaw/concrete\1 (73).JPG
# dataRaw/concrete\1 (74).JPG
# dataRaw/concrete\1 (75).JPG
# dataRaw/concrete\1 (76).JPG
# dataRaw/concrete\1 (77).JPG
# dataRaw/concrete\1 (78).JPG
# dataRaw/concrete\1 (79).jpg
# dataRaw/concrete\1 (80).jpg
# dataRaw/concrete\1 (81).jpg
# dataRaw/concrete\1 (82).jpg
# dataRaw/concrete\1 (83).jpg
# dataRaw/concrete\1 (84).jpg
# dataRaw/concrete\1 (85).jpg
# dataRaw/concrete\1 (86).jpg
# 128
# dataRaw/floor\1 (1).jpg
# dataRaw/floor\1 (108).jpg
# dataRaw/floor\1 (110).jpg
# dataRaw/floor\1 (111).jpg
# dataRaw/floor\1 (113).jpg
# dataRaw/floor\1 (116).jpg
# dataRaw/floor\1 (117).jpg
# dataRaw/floor\1 (118).jpg
# dataRaw/floor\1 (125).jpg
# dataRaw/floor\1 (126).jpg
# dataRaw/floor\1 (127).jpg
# dataRaw/floor\1 (128).jpg
# dataRaw/floor\1 (129).jpg
# dataRaw/floor\1 (131).jpg
# dataRaw/floor\1 (132).jpg
# dataRaw/floor\1 (133).jpg
# dataRaw/floor\1 (134).jpg
# dataRaw/floor\1 (137).jpg
# dataRaw/floor\1 (139).jpg
# dataRaw/floor\1 (140).jpg
# dataRaw/floor\1 (141).jpg
# dataRaw/floor\1 (146).jpg
# dataRaw/floor\1 (155).jpg
# dataRaw/floor\1 (156).jpg
# dataRaw/floor\1 (157).jpg
# dataRaw/floor\1 (158).jpg
# dataRaw/floor\1 (159).jpg
# dataRaw/floor\1 (16).jpg
# dataRaw/floor\1 (160).jpg
# dataRaw/floor\1 (161).jpg
# dataRaw/floor\1 (162).jpg
# dataRaw/floor\1 (163).jpg
# dataRaw/floor\1 (164).jpg
# dataRaw/floor\1 (165).jpg
# dataRaw/floor\1 (166).jpg
# dataRaw/floor\1 (167).jpg
# dataRaw/floor\1 (168).jpg
# dataRaw/floor\1 (169).jpg
# dataRaw/floor\1 (170).jpg
# dataRaw/floor\1 (171).jpg
# dataRaw/floor\1 (177).jpg
# dataRaw/floor\1 (178).jpg
# dataRaw/floor\1 (179).jpg
# dataRaw/floor\1 (182).jpg
# dataRaw/floor\1 (183).jpg
# dataRaw/floor\1 (184).jpg
# dataRaw/floor\1 (185).jpg
# dataRaw/floor\1 (187).jpg
# dataRaw/floor\1 (188).jpg
# dataRaw/floor\1 (189).jpg
# dataRaw/floor\1 (190).jpg
# dataRaw/floor\1 (191).jpg
# dataRaw/floor\1 (192).jpg
# dataRaw/floor\1 (193).jpg
# dataRaw/floor\1 (194).jpg
# dataRaw/floor\1 (195).jpg
# dataRaw/floor\1 (196).jpg
# dataRaw/floor\1 (197).jpg
# dataRaw/floor\1 (198).jpg
# dataRaw/floor\1 (199).jpg
# dataRaw/floor\1 (2).jpg
# dataRaw/floor\1 (200).jpg
# dataRaw/floor\1 (202).jpg
# dataRaw/floor\1 (204).jpg
# dataRaw/floor\1 (208).jpg
# dataRaw/floor\1 (21).jpg
# dataRaw/floor\1 (210).jpg
# dataRaw/floor\1 (212).jpg
# dataRaw/floor\1 (213).jpg
# dataRaw/floor\1 (214).jpg
# dataRaw/floor\1 (216).jpg
# dataRaw/floor\1 (220).jpg
# dataRaw/floor\1 (221).jpg
# dataRaw/floor\1 (225).jpg
# dataRaw/floor\1 (23).jpg
# dataRaw/floor\1 (237).jpg
# dataRaw/floor\1 (25).jpg
# dataRaw/floor\1 (251).jpg
# dataRaw/floor\1 (252).jpg
# dataRaw/floor\1 (253).jpg
# dataRaw/floor\1 (254).jpg
# dataRaw/floor\1 (257).jpg
# dataRaw/floor\1 (259).jpg
# dataRaw/floor\1 (26).jpg
# dataRaw/floor\1 (260).jpg
# dataRaw/floor\1 (261).jpg
# dataRaw/floor\1 (266).jpg
# dataRaw/floor\1 (268).jpg
# dataRaw/floor\1 (27).jpg
# dataRaw/floor\1 (270).jpg
# dataRaw/floor\1 (272).jpg
# dataRaw/floor\1 (277).jpg
# dataRaw/floor\1 (278).jpg
# dataRaw/floor\1 (279).jpg
# dataRaw/floor\1 (28).jpg
# dataRaw/floor\1 (283).jpg
# dataRaw/floor\1 (285).jpg
# dataRaw/floor\1 (29).jpg
# dataRaw/floor\1 (290).jpg
# dataRaw/floor\1 (291).jpg
# dataRaw/floor\1 (298).jpg
# dataRaw/floor\1 (30).jpg
# dataRaw/floor\1 (300).jpg
# dataRaw/floor\1 (302).jpg
# dataRaw/floor\1 (43).jpg
# dataRaw/floor\1 (47).jpg
# dataRaw/floor\1 (51).jpg
# dataRaw/floor\1 (52).jpg
# dataRaw/floor\1 (56).jpg
# dataRaw/floor\1 (57).jpg
# dataRaw/floor\1 (6).jpg
# dataRaw/floor\1 (60).jpg
# dataRaw/floor\1 (61).jpg
# dataRaw/floor\1 (63).jpg
# dataRaw/floor\1 (64).jpg
# dataRaw/floor\1 (65).jpg
# dataRaw/floor\1 (66).jpg
# dataRaw/floor\1 (67).jpg
# dataRaw/floor\1 (69).jpg
# dataRaw/floor\1 (71).jpg
# dataRaw/floor\1 (73).jpg
# dataRaw/floor\1 (74).jpg
# dataRaw/floor\1 (78).jpg
# dataRaw/floor\1 (83).jpg
# dataRaw/floor\1 (84).jpg
# dataRaw/floor\1 (91).jpg
# dataRaw/floor\1 (93).jpg
# dataRaw/floor\1 (97).jpg
# 24
# dataRaw/grass\1 (1).jpg
# dataRaw/grass\1 (10).jpg
# dataRaw/grass\1 (11).jpg
# dataRaw/grass\1 (12).jpg
# dataRaw/grass\1 (13).jpg
# dataRaw/grass\1 (14).jpg
# dataRaw/grass\1 (15).JPG
# dataRaw/grass\1 (16).jpg
# dataRaw/grass\1 (17).jpg
# dataRaw/grass\1 (18).jpg
# dataRaw/grass\1 (19).jpg
# dataRaw/grass\1 (2).jpg
# dataRaw/grass\1 (20).jpg
# dataRaw/grass\1 (3).jpg
# dataRaw/grass\1 (4).jpg
# dataRaw/grass\1 (5).jpg
# dataRaw/grass\1 (6).jpg
# dataRaw/grass\1 (7).jpg
# dataRaw/grass\1 (8).jpg
# dataRaw/grass\1 (9).jpg
# dataRaw/grass\g07.jpg
# dataRaw/grass\Ggfol.jpg
# dataRaw/grass\Grass2.jpg
# dataRaw/grass\Jandi8.jpg
# 50
# dataRaw/roop\1 (1).jpg
# dataRaw/roop\1 (10).jpg
# dataRaw/roop\1 (11).jpg
# dataRaw/roop\1 (12).jpg
# dataRaw/roop\1 (13).jpg
# dataRaw/roop\1 (14).jpg
# dataRaw/roop\1 (15).jpg
# dataRaw/roop\1 (16).jpg
# dataRaw/roop\1 (17).jpg
# dataRaw/roop\1 (18).jpg
# dataRaw/roop\1 (19).jpg
# dataRaw/roop\1 (2).jpg
# dataRaw/roop\1 (20).jpg
# dataRaw/roop\1 (21).jpg
# dataRaw/roop\1 (22).jpg
# dataRaw/roop\1 (23).jpg
# dataRaw/roop\1 (24).jpg
# dataRaw/roop\1 (25).jpg
# dataRaw/roop\1 (26).jpg
# dataRaw/roop\1 (27).jpg
# dataRaw/roop\1 (28).jpg
# dataRaw/roop\1 (29).jpg
# dataRaw/roop\1 (3).jpg
# dataRaw/roop\1 (30).jpg
# dataRaw/roop\1 (31).jpg
# dataRaw/roop\1 (32).jpg
# dataRaw/roop\1 (33).jpg
# dataRaw/roop\1 (34).jpg
# dataRaw/roop\1 (35).jpg
# dataRaw/roop\1 (36).jpg
# dataRaw/roop\1 (37).jpg
# dataRaw/roop\1 (38).jpg
# dataRaw/roop\1 (39).jpg
# dataRaw/roop\1 (4).jpg
# dataRaw/roop\1 (40).jpg
# dataRaw/roop\1 (41).jpg
# dataRaw/roop\1 (42).jpg
# dataRaw/roop\1 (43).jpg
# dataRaw/roop\1 (44).jpg
# dataRaw/roop\1 (45).jpg
# dataRaw/roop\1 (46).jpg
# dataRaw/roop\1 (47).jpg
# dataRaw/roop\1 (48).jpg
# dataRaw/roop\1 (49).jpg
# dataRaw/roop\1 (5).jpg
# dataRaw/roop\1 (50).jpg
# dataRaw/roop\1 (6).jpg
# dataRaw/roop\1 (7).jpg
# dataRaw/roop\1 (8).jpg
# dataRaw/roop\1 (9).jpg
# 37
# dataRaw/sidewalk\1 (1).jpg
# dataRaw/sidewalk\1 (10).jpg
# dataRaw/sidewalk\1 (11).jpg
# dataRaw/sidewalk\1 (12).jpg
# dataRaw/sidewalk\1 (13).jpg
# dataRaw/sidewalk\1 (14).jpg
# dataRaw/sidewalk\1 (15).jpg
# dataRaw/sidewalk\1 (16).jpg
# dataRaw/sidewalk\1 (17).jpg
# dataRaw/sidewalk\1 (18).jpg
# dataRaw/sidewalk\1 (19).jpg
# dataRaw/sidewalk\1 (2).jpg
# dataRaw/sidewalk\1 (20).jpg
# dataRaw/sidewalk\1 (21).jpg
# dataRaw/sidewalk\1 (22).jpg
# dataRaw/sidewalk\1 (23).jpg
# dataRaw/sidewalk\1 (24).jpg
# dataRaw/sidewalk\1 (25).jpg
# dataRaw/sidewalk\1 (26).jpg
# dataRaw/sidewalk\1 (27).jpg
# dataRaw/sidewalk\1 (28).jpg
# dataRaw/sidewalk\1 (29).jpg
# dataRaw/sidewalk\1 (3).JPG
# dataRaw/sidewalk\1 (30).jpg
# dataRaw/sidewalk\1 (31).jpg
# dataRaw/sidewalk\1 (32).jpg
# dataRaw/sidewalk\1 (33).jpg
# dataRaw/sidewalk\1 (34).jpg
# dataRaw/sidewalk\1 (35).jpg
# dataRaw/sidewalk\1 (36).jpg
# dataRaw/sidewalk\1 (37).jpg
# dataRaw/sidewalk\1 (4).JPG
# dataRaw/sidewalk\1 (5).jpg
# dataRaw/sidewalk\1 (6).jpg
# dataRaw/sidewalk\1 (7).jpg
# dataRaw/sidewalk\1 (8).JPG
# dataRaw/sidewalk\1 (9).JPG
# 84
# dataRaw/wall\1 (1).jpg
# dataRaw/wall\1 (10).jpg
# dataRaw/wall\1 (11).jpg
# dataRaw/wall\1 (12).jpg
# dataRaw/wall\1 (13).jpg
# dataRaw/wall\1 (14).jpg
# dataRaw/wall\1 (15).jpg
# dataRaw/wall\1 (16).jpg
# dataRaw/wall\1 (17).jpg
# dataRaw/wall\1 (18).jpg
# dataRaw/wall\1 (19).jpg
# dataRaw/wall\1 (20).jpg
# dataRaw/wall\1 (21).jpg
# dataRaw/wall\1 (22).jpg
# dataRaw/wall\1 (23).jpg
# dataRaw/wall\1 (24).jpg
# dataRaw/wall\1 (25).jpg
# dataRaw/wall\1 (26).jpg
# dataRaw/wall\1 (27).jpg
# dataRaw/wall\1 (28).jpg
# dataRaw/wall\1 (29).jpg
# dataRaw/wall\1 (30).jpg
# dataRaw/wall\1 (31).jpg
# dataRaw/wall\1 (32).jpg
# dataRaw/wall\1 (33).jpg
# dataRaw/wall\1 (34).jpg
# dataRaw/wall\1 (35).jpg
# dataRaw/wall\1 (36).jpg
# dataRaw/wall\1 (37).jpg
# dataRaw/wall\1 (38).jpg
# dataRaw/wall\1 (39).jpg
# dataRaw/wall\1 (4).jpg
# dataRaw/wall\1 (40).jpg
# dataRaw/wall\1 (41).jpg
# dataRaw/wall\1 (42).jpg
# dataRaw/wall\1 (43).jpg
# dataRaw/wall\1 (44).jpg
# dataRaw/wall\1 (45).jpg
# dataRaw/wall\1 (46).jpg
# dataRaw/wall\1 (47).jpg
# dataRaw/wall\1 (48).jpg
# dataRaw/wall\1 (49).jpg
# dataRaw/wall\1 (50).jpg
# dataRaw/wall\1 (51).jpg
# dataRaw/wall\1 (52).jpg
# dataRaw/wall\1 (53).jpg
# dataRaw/wall\1 (54).jpg
# dataRaw/wall\1 (55).jpg
# dataRaw/wall\1 (56).jpg
# dataRaw/wall\1 (57).jpg
# dataRaw/wall\1 (58).jpg
# dataRaw/wall\1 (59).jpg
# dataRaw/wall\1 (6).jpg
# dataRaw/wall\1 (60).jpg
# dataRaw/wall\1 (61).jpg
# dataRaw/wall\1 (62).jpg
# dataRaw/wall\1 (63).jpg
# dataRaw/wall\1 (64).jpg
# dataRaw/wall\1 (65).jpg
# dataRaw/wall\1 (66).jpg
# dataRaw/wall\1 (67).jpg
# dataRaw/wall\1 (68).jpg
# dataRaw/wall\1 (69).jpg
# dataRaw/wall\1 (7).jpg
# dataRaw/wall\1 (70).jpg
# dataRaw/wall\1 (71).jpg
# dataRaw/wall\1 (72).jpg
# dataRaw/wall\1 (73).jpg
# dataRaw/wall\1 (74).jpg
# dataRaw/wall\1 (75).jpg
# dataRaw/wall\1 (76).jpg
# dataRaw/wall\1 (77).jpg
# dataRaw/wall\1 (78).jpg
# dataRaw/wall\1 (79).jpg
# dataRaw/wall\1 (8).jpg
# dataRaw/wall\1 (80).jpg
# dataRaw/wall\1 (81).jpg
# dataRaw/wall\1 (82).jpg
# dataRaw/wall\1 (83).jpg
# dataRaw/wall\1 (84).jpg
# dataRaw/wall\1 (85).jpg
# dataRaw/wall\1 (86).jpg
# dataRaw/wall\1 (87).jpg
# dataRaw/wall\1 (9).jpg

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
PATH_SAVED = "dataProcessed"
files = glob.glob(PATH_SAVED + "/*.*")

im = cv2.imread (files[3], cv2.IMREAD_COLOR)
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
# img = tf.keras.preprocessing.image.array_to_img(im)

array = tf.keras.preprocessing.image.img_to_array(im)
plt.imshow(array/255)

# %%
PATH_SAVED = "dataProcessed"
files = glob.glob(PATH_SAVED + "/*.*")
classList = []

for f in files:
    type = f.split('\\')[-1].split('_')[0]
    if type not in classList:
        classList.append(type)
print(classList)

np.random.shuffle(files)

data = []
target = []
for f in files:
    type = f.split('\\')[-1].split('_')[0]
    if (type in classList):
        id = classList.index(type)
        target.append(id)

        im = cv2.imread (f, cv2.IMREAD_COLOR)
        im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
        array = tf.keras.preprocessing.image.img_to_array(im)
        # array.resize(DIM[0]))
        data.append(array)
        # plt.imshow(array/255)
        # break
    # print(data[0])

dataArray = np.array(data)
# dataArray = tf.expand_dims(dataArray, axis=-1)
# Out:
# ['brick', 'concrete', 'floor', 'grass', 'roop', 'sidewalk', 'wall']

# %%
dataArray.shape
# Out:
# (427, 100, 100, 3)

# %%
# dataArray = tf.random.shuffle(dataArray, seed=0, name=None )
# target = tf.random.shuffle(target, seed=0, name=None )

# %%
# target.numpy()

# %%
index = 6
print(classList[target[index]])
plt.imshow(dataArray[index]/255)
# Out:
# roop

# %%
print(len(target))
target
# Out:
# 427
# [2,
#  6,
#  6,
#  2,
#  0,
#  6,
#  4,
#  2,
#  1,
#  0,
#  0,
#  2,
#  1,
#  2,
#  6,
#  6,
#  1,
#  1,
#  2,
#  4,
#  1,
#  2,
#  6,
#  2,
#  0,
#  4,
#  4,
#  5,
#  2,
#  6,
#  2,
#  0,
#  2,
#  4,
#  4,
#  0,
#  5,
#  4,
#  2,
#  2,
#  5,
#  4,
#  1,
#  4,
#  5,
#  3,
#  1,
#  0,
#  0,
#  5,
#  6,
#  2,
#  6,
#  0,
#  2,
#  0,
#  2,
#  4,
#  6,
#  0,
#  2,
#  1,
#  6,
#  2,
#  3,
#  5,
#  5,
#  0,
#  2,
#  2,
#  6,
#  6,
#  6,
#  2,
#  2,
#  0,
#  6,
#  6,
#  4,
#  4,
#  2,
#  2,
#  6,
#  2,
#  2,
#  3,
#  3,
#  2,
#  6,
#  2,
#  5,
#  6,
#  5,
#  5,
#  6,
#  6,
#  2,
#  5,
#  2,
#  2,
#  4,
#  6,
#  6,
#  1,
#  6,
#  6,
#  5,
#  4,
#  4,
#  2,
#  1,
#  4,
#  0,
#  1,
#  0,
#  4,
#  6,
#  2,
#  2,
#  5,
#  2,
#  0,
#  6,
#  0,
#  1,
#  0,
#  0,
#  6,
#  2,
#  2,
#  0,
#  2,
#  2,
#  2,
#  2,
#  0,
#  2,
#  6,
#  4,
#  4,
#  3,
#  6,
#  2,
#  0,
#  2,
#  4,
#  0,
#  2,
#  2,
#  2,
#  3,
#  1,
#  1,
#  5,
#  2,
#  2,
#  6,
#  2,
#  0,
#  2,
#  1,
#  1,
#  6,
#  2,
#  0,
#  2,
#  0,
#  2,
#  2,
#  6,
#  5,
#  0,
#  6,
#  0,
#  3,
#  4,
#  1,
#  6,
#  2,
#  2,
#  6,
#  4,
#  6,
#  2,
#  2,
#  2,
#  2,
#  5,
#  3,
#  4,
#  2,
#  2,
#  2,
#  1,
#  6,
#  6,
#  3,
#  6,
#  1,
#  2,
#  5,
#  6,
#  2,
#  3,
#  2,
#  2,
#  6,
#  6,
#  6,
#  0,
#  5,
#  2,
#  6,
#  4,
#  3,
#  5,
#  0,
#  2,
#  1,
#  5,
#  4,
#  2,
#  2,
#  2,
#  4,
#  0,
#  0,
#  1,
#  6,
#  2,
#  2,
#  5,
#  6,
#  2,
#  1,
#  6,
#  6,
#  2,
#  0,
#  1,
#  4,
#  1,
#  2,
#  0,
#  5,
#  3,
#  3,
#  0,
#  6,
#  2,
#  6,
#  4,
#  1,
#  6,
#  6,
#  2,
#  6,
#  2,
#  6,
#  2,
#  6,
#  1,
#  4,
#  4,
#  0,
#  5,
#  2,
#  3,
#  6,
#  6,
#  6,
#  4,
#  0,
#  2,
#  2,
#  2,
#  2,
#  2,
#  4,
#  2,
#  0,
#  0,
#  0,
#  6,
#  2,
#  2,
#  1,
#  5,
#  1,
#  4,
#  6,
#  0,
#  3,
#  0,
#  6,
#  1,
#  3,
#  2,
#  2,
#  6,
#  2,
#  4,
#  2,
#  5,
#  1,
#  1,
#  2,
#  4,
#  3,
#  4,
#  2,
#  1,
#  5,
#  2,
#  6,
#  1,
#  3,
#  6,
#  2,
#  6,
#  2,
#  1,
#  6,
#  2,
#  0,
#  2,
#  4,
#  5,
#  4,
#  6,
#  2,
#  3,
#  4,
#  2,
#  4,
#  0,
#  2,
#  6,
#  4,
#  0,
#  2,
#  2,
#  2,
#  2,
#  3,
#  1,
#  0,
#  3,
#  6,
#  1,
#  4,
#  4,
#  5,
#  5,
#  1,
#  6,
#  2,
#  0,
#  1,
#  2,
#  2,
#  0,
#  3,
#  2,
#  0,
#  2,
#  2,
#  0,
#  6,
#  1,
#  2,
#  4,
#  4,
#  6,
#  5,
#  4,
#  6,
#  0,
#  0,
#  6,
#  2,
#  1,
#  6,
#  5,
#  6,
#  2,
#  2,
#  6,
#  4,
#  2,
#  4,
#  0,
#  6,
#  5,
#  2,
#  4,
#  1,
#  5,
#  2,
#  2,
#  5,
#  1,
#  4,
#  0,
#  1,
#  6,
#  5,
#  6,
#  1,
#  6,
#  2,
#  0,
#  6,
#  1,
#  3,
#  6,
#  0,
#  2,
#  3,
#  5,
#  0,
#  2,
#  2,
#  2,
#  5,
#  1,
#  0]
