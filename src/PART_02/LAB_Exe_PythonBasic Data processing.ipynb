# %% [markdown]
# # **Introduction to Computational Design: Data, Geometry, and Visualization Using Digital Media**
#
# DigitalFUTURES WORLD : ARCHITECTS UNITE Workshops
# https://medium.com/@nj.namju/14161fdfd22f
# ***
# instructor: NJ Namju Lee
#
# email: nj.namju@gmail.com
#
# www.njstudio.co.kr
#
# Medium: https://medium.com/p/14161fdfd22f
#
# Grasshopper Python: https://www.dropbox.com/s/4om57u5egbl0wtz/ITCD_day1_python_basic_grasshopper.gh?dl=0

# %% [markdown]
# # Python basic

# %% [markdown]
# ## Basic Syntax

# %% [markdown]
# 1. domain

# %%
A = 0
B = 10
N = 4

interval = (B - A) / N

outList = [];
for i in range(N + 1):
    result = A + ( i * interval ) 
    outList.append(result);

a = outList
print(a)
# Out:
# [0.0, 2.5, 5.0, 7.5, 10.0]

# %%
# your code here

# %% [markdown]
# 2. Series

# %%
S = 1
N = 10
C = 4


outList = [];
for i in range(C):
    result = S + ( i * N  )
    outList.append(result);

a = outList
print(a)
# Out:
# [1, 11, 21, 31]

# %%
# your code here

# %% [markdown]
# 3. Remap

# %%
V = 8
sMin = 0.0;
sMax = 10.00
tMin = 0;
tMax = 51.4

result  = (((V - sMin) * (tMax - tMin)) / (sMax - sMin)) + tMin;
print(result)
# Out:
# 41.12

# %%
# your code here

# %% [markdown]
# 3 item

# %%
i = 10
L = ['a', 'b', 'c', 'd', 1, 2, 3, 4];
W = True;

if W == True:
    print(L[int(i % len(L))]);
else :
    try:
        print(L[i])
    except:
        print('out of range');
# Out:
# c

# %% [markdown]
# 4. Split strings

# %%
outList = [];
for i in T.split(","):
    outList.append(i);

a = outList;

# %% [markdown]
# 5. Reverse String data

# %%
newTextArray = [];
txt = 'helloWorld';
textOut = ''

for i in txt:
  newTextArray.append(i)

for i in range( int(len(newTextArray) / 2)):
  temp = newTextArray[i];
  newTextArray[i] = newTextArray[len(newTextArray) - i - 1];
  newTextArray[len(newTextArray) - i - 1] = temp;

for i in newTextArray:
  textOut+= i

print(textOut)
# Out:
# dlroWolleh

# %%
txt = 'helloWorld';

txtReverse = txt[::-1]

print(txtReverse)
# Out:
# dlroWolleh

# %% [markdown]
# ## Additional Reading and Resources
#
# #### python documentation(3.x)
# https://docs.python.org/3/
#
# #### codecademy
# https://www.codecademy.com/learn/learn-python-3
#
# ### Think Python
# https://www.greenteapress.com/thinkpython/thinkpython.pdf
