# %% [markdown]
# # **Data in Design, AI for Urban Data and Visualization**
#
# #### Data, Design Computation, Artificial Intelligence, Visualization, Harvard GSD
#
# **KEYWORD:**
# Vector, Raster, Urban Data, GIS, Data Processing, Data Mining, Machine Learning, Artificial Intelligence, Visualization, Mapping, Design Decision-Making
#
# -----
#
# #### Instructor : NJ Namju Lee / nj.namju@gmail.com
# ###### * Linkedin - https://www.linkedin.com/in/nj-namju-lee-926b3252/    * Git - https://github.com/NamjuLee
#
# ###### * Web - http://www.njstudio.co.kr                                  * Lab - http://www.njslab.com/NJSLabCore/
#
# ###### * Video(English) - https://www.youtube.com/c/njnamjulee            * Writing(English) - https://medium.com/@nj-namju
#
# ###### * Video(Korean) - https://www.youtube.com/c/CodeforDesign          * Writing(Korean) - https://brunch.co.kr/@njnamju
# -----

# %% [markdown]
# ### [Colab version](https://colab.research.google.com/drive/1LOP36_Z46P4rJ5D2D5lE4P1OMDgOzMUJ#scrollTo=X2XXbVGI4Zwf)

# %%
import sys
import os

import numpy as np
import pandas as pd

print('----------------------------')
print('numpy:', np.__version__)
print('pandas:', pd.__version__)

import tensorflow as tf
print('tensorflow', tf.__version__)
print('python', sys.version)
print('----------------------------')
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
print('keras',keras.__version__);

from sklearn.model_selection import train_test_split
import math

import matplotlib.pyplot as plt
# Out:
# ----------------------------
# numpy: 1.19.5
# pandas: 1.3.4
# tensorflow 2.5.2
# python 3.9.9 | packaged by conda-forge | (main, Dec 20 2021, 02:36:06) [MSC v.1929 64 bit (AMD64)]
# ----------------------------
# keras 2.5.0

# %%
# for google colab
# from google.colab import drive 
# drive.mount('/content/gdrive')
# pathFileName = "gdrive/My Drive/njs-python-core/Workshop/SmartDrawing/data/vector/vectorData.csv"
# # df=pd.read_csv('pathFileName')
# dataSet = np.loadtxt(pathFileName, delimiter=',')

# %%
# import prepared data
dataSet = np.loadtxt( 'data/vector/vectorData.csv', delimiter=',')
Y = dataSet[:,-1:]
X = dataSet[:,:-1]
print('dim class: ', Y.shape)
print('dim mat: ', X.shape)

np.random.seed(222)
# np.random.shuffle(dataSet)
# Out:
# dim class:  (530, 1)
# dim mat:  (530, 501)

# %%
def DataPreProcessing(d, testSize = 0.3):
    Y = d[:,-1:]
    X = d[:,:-1]
    print('dim class: ', Y.shape)
    print('dim mat: ', X.shape)

    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=testSize, random_state=0)
    
    return [X_train, X_test, Y_train, Y_test]

# %%
theModelFitHistory = []
theModelStatic = []
def TrainNetwork(X_train, X_test, Y_train, Y_test, epochs=100, networkType = 0, testSize = 0.3, batchSize=15 ,autoStop = False ):

    Y_train = tf.keras.utils.to_categorical(Y_train)
    Y_test = tf.keras.utils.to_categorical(Y_test)
        
    xDim = X_train.shape[1]
    yDim = Y_train.shape[1]
    
    model = Sequential()
    
    MODEL_DIR = './model/modelMultiClassification/'
    if not os.path.exists(MODEL_DIR):
        os.mkdir(MODEL_DIR)

    modelpath="./model/modelMultiClassification/Network_"+str(networkType)+"_{epoch:02d}-{val_loss:.4f}.hdf5"
    checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
    early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)
    
    if networkType == 0:
        model.add(Dense(30, input_dim=xDim, activation='relu'))
        model.add(Dense(12, activation='relu'))
        model.add(Dense(yDim, activation='softmax'))
    
    elif networkType == 1:  
        model.add(Dense(30,  input_dim=xDim, activation='relu'))
        model.add(Dense(12, activation='relu'))
        model.add(Dense(8, activation='relu'))
        model.add(Dense(yDim, activation='softmax'))
 
    elif networkType == 2: 
        model.add(Dense(64,  input_dim=xDim, activation='relu'))
        model.add(Dense(32, activation='relu'))
        model.add(Dense(12, activation='relu'))
        model.add(Dense(8, activation='relu'))
        model.add(Dense(yDim, activation='softmax'))
    
    elif networkType == 3: 
        model.add(Dense(64,  input_dim=xDim, activation='relu'))
        model.add(Dense(32, activation='relu'))
        model.add(Dense(12, activation='relu'))
        model.add(Dense(8, activation='relu'))
        model.add(Dense(yDim, activation='softmax'))
    
    elif networkType == 4: 
        model.add(Dense(128,  input_dim=xDim, activation='relu'))
        model.add(Dense(64, activation='relu'))
        model.add(Dense(32, activation='relu'))
        model.add(Dense(12, activation='relu'))
        model.add(Dense(yDim, activation='softmax'))
    
    elif networkType == 5: 
        model.add(Dense(128,  input_dim=xDim, activation='relu'))
        model.add(Dense(64, activation='relu'))
        model.add(Dense(32, activation='relu'))
        model.add(Dense(12, activation='relu'))
        model.add(Dense(8, activation='relu'))
        model.add(Dense(yDim, activation='softmax'))

                        # binary_crossentropy
    model.compile(loss='categorical_crossentropy', optimizer='adam',  metrics=['accuracy'])
    if autoStop:
        modelFitHistory = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), 
                                    epochs=epochs, batch_size=batchSize, verbose=0, 
                                    callbacks=[early_stopping_callback,checkpointer])
    else:
        modelFitHistory = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), 
                                    epochs=epochs, batch_size=batchSize, verbose=0,)     
        
    theModelFitHistory.append(modelFitHistory);
    
    print('-----------------------')
    print('network:', networkType)
    print('done for fitting')
    
    theModelStatic.append(model)
    
    # tfjs.converters.save_keras_model(model, tfjs_target_dir)
    # Y_prediction = model.predict(X_test).flatten()

    # Y_prediction = model.predict(X_test)
    # print(Y_prediction);
    # print(Y_test)
    
    # Y_prediction = model.evaluate(X_test, Y_test)
    # print(Y_prediction)

    score = model.evaluate(X_test, Y_test, verbose=1)
    print('Test loss:', score[0])
    print('Test accuracy:', score[1])

    return score

# %%
print(dataSet[0][0])
# Out:
# 1.0

# %%
import time

theModelFitHistory = []
theModelStatic = []

epochs = 100
numNetwork = 6
resultArrayOfArray = []

resultArray = []
dataForTrain = DataPreProcessing(dataSet, testSize = 0.15)

for i in range(numNetwork):
    start = time.time()
    yPredictionSet = TrainNetwork(
        dataForTrain[0],dataForTrain[1],dataForTrain[2],dataForTrain[3],
        epochs=epochs, networkType=i, 
        batchSize=50, autoStop = True
        )
    resultArray.append(yPredictionSet)
    end = time.time()
    print("time ", end - start)
resultArrayOfArray.append(resultArray)
print('============================================')
# Out:
# dim class:  (530, 1)
# dim mat:  (530, 501)
#
# Epoch 00001: val_loss improved from inf to 1.95975, saving model to ./model/modelMultiClassification\Network_0_01-1.9598.hdf5
#
# Epoch 00002: val_loss improved from 1.95975 to 1.80752, saving model to ./model/modelMultiClassification\Network_0_02-1.8075.hdf5
#
# Epoch 00003: val_loss improved from 1.80752 to 1.73242, saving model to ./model/modelMultiClassification\Network_0_03-1.7324.hdf5
#
# Epoch 00004: val_loss improved from 1.73242 to 1.64043, saving model to ./model/modelMultiClassification\Network_0_04-1.6404.hdf5
#
# Epoch 00005: val_loss improved from 1.64043 to 1.58203, saving model to ./model/modelMultiClassification\Network_0_05-1.5820.hdf5
#
# Epoch 00006: val_loss improved from 1.58203 to 1.53667, saving model to ./model/modelMultiClassification\Network_0_06-1.5367.hdf5
#
# Epoch 00007: val_loss improved from 1.53667 to 1.48852, saving model to ./model/modelMultiClassification\Network_0_07-1.4885.hdf5
#
# Epoch 00008: val_loss improved from 1.48852 to 1.44664, saving model to ./model/modelMultiClassification\Network_0_08-1.4466.hdf5
#
# Epoch 00009: val_loss improved from 1.44664 to 1.41383, saving model to ./model/modelMultiClassification\Network_0_09-1.4138.hdf5
#
# Epoch 00010: val_loss improved from 1.41383 to 1.36889, saving model to ./model/modelMultiClassification\Network_0_10-1.3689.hdf5
#
# Epoch 00011: val_loss improved from 1.36889 to 1.36753, saving model to ./model/modelMultiClassification\Network_0_11-1.3675.hdf5
#
# Epoch 00012: val_loss improved from 1.36753 to 1.32916, saving model to ./model/modelMultiClassification\Network_0_12-1.3292.hdf5
#
# Epoch 00013: val_loss improved from 1.32916 to 1.32186, saving model to ./model/modelMultiClassification\Network_0_13-1.3219.hdf5
#
# Epoch 00014: val_loss improved from 1.32186 to 1.30728, saving model to ./model/modelMultiClassification\Network_0_14-1.3073.hdf5
#
# Epoch 00015: val_loss improved from 1.30728 to 1.25186, saving model to ./model/modelMultiClassification\Network_0_15-1.2519.hdf5
#
# Epoch 00016: val_loss improved from 1.25186 to 1.24488, saving model to ./model/modelMultiClassification\Network_0_16-1.2449.hdf5
#
# Epoch 00017: val_loss did not improve from 1.24488
#
# Epoch 00018: val_loss improved from 1.24488 to 1.24090, saving model to ./model/modelMultiClassification\Network_0_18-1.2409.hdf5
#
# Epoch 00019: val_loss improved from 1.24090 to 1.23516, saving model to ./model/modelMultiClassification\Network_0_19-1.2352.hdf5
#
# Epoch 00020: val_loss improved from 1.23516 to 1.21743, saving model to ./model/modelMultiClassification\Network_0_20-1.2174.hdf5
#
# Epoch 00021: val_loss did not improve from 1.21743
#
# Epoch 00022: val_loss did not improve from 1.21743
#
# Epoch 00023: val_loss did not improve from 1.21743
#
# Epoch 00024: val_loss did not improve from 1.21743
#
# Epoch 00025: val_loss improved from 1.21743 to 1.21630, saving model to ./model/modelMultiClassification\Network_0_25-1.2163.hdf5
#
# Epoch 00026: val_loss did not improve from 1.21630
#
# Epoch 00027: val_loss improved from 1.21630 to 1.20166, saving model to ./model/modelMultiClassification\Network_0_27-1.2017.hdf5
#
# Epoch 00028: val_loss did not improve from 1.20166
#
# Epoch 00029: val_loss did not improve from 1.20166
#
# Epoch 00030: val_loss did not improve from 1.20166
#
# Epoch 00031: val_loss improved from 1.20166 to 1.17962, saving model to ./model/modelMultiClassification\Network_0_31-1.1796.hdf5
#
# Epoch 00032: val_loss did not improve from 1.17962
#
# Epoch 00033: val_loss did not improve from 1.17962
#
# Epoch 00034: val_loss did not improve from 1.17962
#
# Epoch 00035: val_loss improved from 1.17962 to 1.16562, saving model to ./model/modelMultiClassification\Network_0_35-1.1656.hdf5
#
# Epoch 00036: val_loss did not improve from 1.16562
#
# Epoch 00037: val_loss did not improve from 1.16562
#
# Epoch 00038: val_loss did not improve from 1.16562
#
# Epoch 00039: val_loss did not improve from 1.16562
#
# Epoch 00040: val_loss did not improve from 1.16562
#
# Epoch 00041: val_loss did not improve from 1.16562
#
# Epoch 00042: val_loss did not improve from 1.16562
#
# Epoch 00043: val_loss did not improve from 1.16562
#
# Epoch 00044: val_loss did not improve from 1.16562
#
# Epoch 00045: val_loss did not improve from 1.16562
# -----------------------
# network: 0
# done for fitting
# 3/3 [==============================] - 0s 3ms/step - loss: 1.2345 - accuracy: 0.7250
# Test loss: 1.234467625617981
# Test accuracy: 0.7250000238418579
# time  3.5598387718200684
#
# Epoch 00001: val_loss improved from inf to 1.92697, saving model to ./model/modelMultiClassification\Network_1_01-1.9270.hdf5
#
# Epoch 00002: val_loss improved from 1.92697 to 1.80118, saving model to ./model/modelMultiClassification\Network_1_02-1.8012.hdf5
#
# Epoch 00003: val_loss improved from 1.80118 to 1.70649, saving model to ./model/modelMultiClassification\Network_1_03-1.7065.hdf5
#
# Epoch 00004: val_loss improved from 1.70649 to 1.63858, saving model to ./model/modelMultiClassification\Network_1_04-1.6386.hdf5
#
# Epoch 00005: val_loss improved from 1.63858 to 1.60485, saving model to ./model/modelMultiClassification\Network_1_05-1.6049.hdf5
#
# Epoch 00006: val_loss improved from 1.60485 to 1.54164, saving model to ./model/modelMultiClassification\Network_1_06-1.5416.hdf5
#
# Epoch 00007: val_loss improved from 1.54164 to 1.51951, saving model to ./model/modelMultiClassification\Network_1_07-1.5195.hdf5
#
# Epoch 00008: val_loss improved from 1.51951 to 1.48101, saving model to ./model/modelMultiClassification\Network_1_08-1.4810.hdf5
#
# Epoch 00009: val_loss improved from 1.48101 to 1.43445, saving model to ./model/modelMultiClassification\Network_1_09-1.4344.hdf5
#
# Epoch 00010: val_loss improved from 1.43445 to 1.40227, saving model to ./model/modelMultiClassification\Network_1_10-1.4023.hdf5
#
# Epoch 00011: val_loss did not improve from 1.40227
#
# Epoch 00012: val_loss improved from 1.40227 to 1.38200, saving model to ./model/modelMultiClassification\Network_1_12-1.3820.hdf5
#
# Epoch 00013: val_loss improved from 1.38200 to 1.37187, saving model to ./model/modelMultiClassification\Network_1_13-1.3719.hdf5
#
# Epoch 00014: val_loss improved from 1.37187 to 1.35011, saving model to ./model/modelMultiClassification\Network_1_14-1.3501.hdf5
#
# Epoch 00015: val_loss did not improve from 1.35011
#
# Epoch 00016: val_loss improved from 1.35011 to 1.32058, saving model to ./model/modelMultiClassification\Network_1_16-1.3206.hdf5
#
# Epoch 00017: val_loss did not improve from 1.32058
#
# Epoch 00018: val_loss did not improve from 1.32058
#
# Epoch 00019: val_loss did not improve from 1.32058
#
# Epoch 00020: val_loss improved from 1.32058 to 1.31297, saving model to ./model/modelMultiClassification\Network_1_20-1.3130.hdf5
#
# Epoch 00021: val_loss did not improve from 1.31297
#
# Epoch 00022: val_loss improved from 1.31297 to 1.29581, saving model to ./model/modelMultiClassification\Network_1_22-1.2958.hdf5
#
# Epoch 00023: val_loss did not improve from 1.29581
#
# Epoch 00024: val_loss improved from 1.29581 to 1.28371, saving model to ./model/modelMultiClassification\Network_1_24-1.2837.hdf5
#
# Epoch 00025: val_loss did not improve from 1.28371
#
# Epoch 00026: val_loss did not improve from 1.28371
#
# Epoch 00027: val_loss improved from 1.28371 to 1.25267, saving model to ./model/modelMultiClassification\Network_1_27-1.2527.hdf5
#
# Epoch 00028: val_loss improved from 1.25267 to 1.24513, saving model to ./model/modelMultiClassification\Network_1_28-1.2451.hdf5
#
# Epoch 00029: val_loss did not improve from 1.24513
#
# Epoch 00030: val_loss did not improve from 1.24513
#
# Epoch 00031: val_loss improved from 1.24513 to 1.23199, saving model to ./model/modelMultiClassification\Network_1_31-1.2320.hdf5
#
# Epoch 00032: val_loss did not improve from 1.23199
#
# Epoch 00033: val_loss improved from 1.23199 to 1.22880, saving model to ./model/modelMultiClassification\Network_1_33-1.2288.hdf5
#
# Epoch 00034: val_loss improved from 1.22880 to 1.19984, saving model to ./model/modelMultiClassification\Network_1_34-1.1998.hdf5
#
# Epoch 00035: val_loss did not improve from 1.19984
#
# Epoch 00036: val_loss did not improve from 1.19984
#
# Epoch 00037: val_loss improved from 1.19984 to 1.19383, saving model to ./model/modelMultiClassification\Network_1_37-1.1938.hdf5
#
# Epoch 00038: val_loss did not improve from 1.19383
#
# Epoch 00039: val_loss did not improve from 1.19383
#
# Epoch 00040: val_loss did not improve from 1.19383
#
# Epoch 00041: val_loss did not improve from 1.19383
#
# Epoch 00042: val_loss did not improve from 1.19383
#
# Epoch 00043: val_loss did not improve from 1.19383
#
# Epoch 00044: val_loss did not improve from 1.19383
#
# Epoch 00045: val_loss did not improve from 1.19383
#
# Epoch 00046: val_loss did not improve from 1.19383
#
# Epoch 00047: val_loss did not improve from 1.19383
# -----------------------
# network: 1
# done for fitting
# 3/3 [==============================] - 0s 3ms/step - loss: 1.3477 - accuracy: 0.7375
# Test loss: 1.347672939300537
# Test accuracy: 0.737500011920929
# time  3.2231035232543945
#
# Epoch 00001: val_loss improved from inf to 2.12189, saving model to ./model/modelMultiClassification\Network_2_01-2.1219.hdf5
#
# Epoch 00002: val_loss improved from 2.12189 to 2.04844, saving model to ./model/modelMultiClassification\Network_2_02-2.0484.hdf5
#
# Epoch 00003: val_loss improved from 2.04844 to 1.95583, saving model to ./model/modelMultiClassification\Network_2_03-1.9558.hdf5
#
# Epoch 00004: val_loss improved from 1.95583 to 1.89652, saving model to ./model/modelMultiClassification\Network_2_04-1.8965.hdf5
#
# Epoch 00005: val_loss improved from 1.89652 to 1.85006, saving model to ./model/modelMultiClassification\Network_2_05-1.8501.hdf5
#
# Epoch 00006: val_loss improved from 1.85006 to 1.76257, saving model to ./model/modelMultiClassification\Network_2_06-1.7626.hdf5
#
# Epoch 00007: val_loss improved from 1.76257 to 1.66377, saving model to ./model/modelMultiClassification\Network_2_07-1.6638.hdf5
#
# Epoch 00008: val_loss improved from 1.66377 to 1.61478, saving model to ./model/modelMultiClassification\Network_2_08-1.6148.hdf5
#
# Epoch 00009: val_loss improved from 1.61478 to 1.53276, saving model to ./model/modelMultiClassification\Network_2_09-1.5328.hdf5
#
# Epoch 00010: val_loss improved from 1.53276 to 1.51650, saving model to ./model/modelMultiClassification\Network_2_10-1.5165.hdf5
#
# Epoch 00011: val_loss improved from 1.51650 to 1.46956, saving model to ./model/modelMultiClassification\Network_2_11-1.4696.hdf5
#
# Epoch 00012: val_loss improved from 1.46956 to 1.44828, saving model to ./model/modelMultiClassification\Network_2_12-1.4483.hdf5
#
# Epoch 00013: val_loss improved from 1.44828 to 1.40731, saving model to ./model/modelMultiClassification\Network_2_13-1.4073.hdf5
#
# Epoch 00014: val_loss did not improve from 1.40731
#
# Epoch 00015: val_loss improved from 1.40731 to 1.36009, saving model to ./model/modelMultiClassification\Network_2_15-1.3601.hdf5
#
# Epoch 00016: val_loss did not improve from 1.36009
#
# Epoch 00017: val_loss improved from 1.36009 to 1.34583, saving model to ./model/modelMultiClassification\Network_2_17-1.3458.hdf5
#
# Epoch 00018: val_loss did not improve from 1.34583
#
# Epoch 00019: val_loss improved from 1.34583 to 1.32637, saving model to ./model/modelMultiClassification\Network_2_19-1.3264.hdf5
#
# Epoch 00020: val_loss improved from 1.32637 to 1.31951, saving model to ./model/modelMultiClassification\Network_2_20-1.3195.hdf5
#
# Epoch 00021: val_loss improved from 1.31951 to 1.30862, saving model to ./model/modelMultiClassification\Network_2_21-1.3086.hdf5
#
# Epoch 00022: val_loss did not improve from 1.30862
#
# Epoch 00023: val_loss did not improve from 1.30862
#
# Epoch 00024: val_loss did not improve from 1.30862
#
# Epoch 00025: val_loss did not improve from 1.30862
#
# Epoch 00026: val_loss did not improve from 1.30862
#
# Epoch 00027: val_loss improved from 1.30862 to 1.30201, saving model to ./model/modelMultiClassification\Network_2_27-1.3020.hdf5
#
# Epoch 00028: val_loss improved from 1.30201 to 1.24765, saving model to ./model/modelMultiClassification\Network_2_28-1.2477.hdf5
#
# Epoch 00029: val_loss did not improve from 1.24765
#
# Epoch 00030: val_loss did not improve from 1.24765
#
# Epoch 00031: val_loss did not improve from 1.24765
#
# Epoch 00032: val_loss did not improve from 1.24765
#
# Epoch 00033: val_loss did not improve from 1.24765
#
# Epoch 00034: val_loss did not improve from 1.24765
#
# Epoch 00035: val_loss did not improve from 1.24765
#
# Epoch 00036: val_loss did not improve from 1.24765
#
# Epoch 00037: val_loss did not improve from 1.24765
#
# Epoch 00038: val_loss did not improve from 1.24765
# -----------------------
# network: 2
# done for fitting
# 3/3 [==============================] - 0s 2ms/step - loss: 1.4000 - accuracy: 0.7000
# Test loss: 1.400032639503479
# Test accuracy: 0.699999988079071
# time  3.1148619651794434
#
# Epoch 00001: val_loss improved from inf to 1.99121, saving model to ./model/modelMultiClassification\Network_3_01-1.9912.hdf5
#
# Epoch 00002: val_loss improved from 1.99121 to 1.88604, saving model to ./model/modelMultiClassification\Network_3_02-1.8860.hdf5
#
# Epoch 00003: val_loss improved from 1.88604 to 1.81308, saving model to ./model/modelMultiClassification\Network_3_03-1.8131.hdf5
#
# Epoch 00004: val_loss improved from 1.81308 to 1.74701, saving model to ./model/modelMultiClassification\Network_3_04-1.7470.hdf5
#
# Epoch 00005: val_loss improved from 1.74701 to 1.68852, saving model to ./model/modelMultiClassification\Network_3_05-1.6885.hdf5
#
# Epoch 00006: val_loss improved from 1.68852 to 1.63081, saving model to ./model/modelMultiClassification\Network_3_06-1.6308.hdf5
#
# Epoch 00007: val_loss improved from 1.63081 to 1.57662, saving model to ./model/modelMultiClassification\Network_3_07-1.5766.hdf5
#
# Epoch 00008: val_loss improved from 1.57662 to 1.55453, saving model to ./model/modelMultiClassification\Network_3_08-1.5545.hdf5
#
# Epoch 00009: val_loss improved from 1.55453 to 1.46938, saving model to ./model/modelMultiClassification\Network_3_09-1.4694.hdf5
#
# Epoch 00010: val_loss improved from 1.46938 to 1.45127, saving model to ./model/modelMultiClassification\Network_3_10-1.4513.hdf5
#
# Epoch 00011: val_loss improved from 1.45127 to 1.38811, saving model to ./model/modelMultiClassification\Network_3_11-1.3881.hdf5
#
# Epoch 00012: val_loss improved from 1.38811 to 1.37276, saving model to ./model/modelMultiClassification\Network_3_12-1.3728.hdf5
#
# Epoch 00013: val_loss improved from 1.37276 to 1.31038, saving model to ./model/modelMultiClassification\Network_3_13-1.3104.hdf5
#
# Epoch 00014: val_loss improved from 1.31038 to 1.28606, saving model to ./model/modelMultiClassification\Network_3_14-1.2861.hdf5
#
# Epoch 00015: val_loss improved from 1.28606 to 1.24058, saving model to ./model/modelMultiClassification\Network_3_15-1.2406.hdf5
#
# Epoch 00016: val_loss improved from 1.24058 to 1.22926, saving model to ./model/modelMultiClassification\Network_3_16-1.2293.hdf5
#
# Epoch 00017: val_loss did not improve from 1.22926
#
# Epoch 00018: val_loss improved from 1.22926 to 1.20889, saving model to ./model/modelMultiClassification\Network_3_18-1.2089.hdf5
#
# Epoch 00019: val_loss did not improve from 1.20889
#
# Epoch 00020: val_loss did not improve from 1.20889
#
# Epoch 00021: val_loss did not improve from 1.20889
#
# Epoch 00022: val_loss did not improve from 1.20889
#
# Epoch 00023: val_loss did not improve from 1.20889
#
# Epoch 00024: val_loss did not improve from 1.20889
#
# Epoch 00025: val_loss did not improve from 1.20889
#
# Epoch 00026: val_loss did not improve from 1.20889
#
# Epoch 00027: val_loss did not improve from 1.20889
#
# Epoch 00028: val_loss did not improve from 1.20889
# -----------------------
# network: 3
# done for fitting
# 3/3 [==============================] - 0s 2ms/step - loss: 1.2827 - accuracy: 0.7375
# Test loss: 1.2827322483062744
# Test accuracy: 0.737500011920929
# time  3.3454127311706543
#
# Epoch 00001: val_loss improved from inf to 1.77134, saving model to ./model/modelMultiClassification\Network_4_01-1.7713.hdf5
#
# Epoch 00002: val_loss improved from 1.77134 to 1.58441, saving model to ./model/modelMultiClassification\Network_4_02-1.5844.hdf5
#
# Epoch 00003: val_loss improved from 1.58441 to 1.44415, saving model to ./model/modelMultiClassification\Network_4_03-1.4442.hdf5
#
# Epoch 00004: val_loss improved from 1.44415 to 1.34646, saving model to ./model/modelMultiClassification\Network_4_04-1.3465.hdf5
#
# Epoch 00005: val_loss improved from 1.34646 to 1.33901, saving model to ./model/modelMultiClassification\Network_4_05-1.3390.hdf5
#
# Epoch 00006: val_loss improved from 1.33901 to 1.33892, saving model to ./model/modelMultiClassification\Network_4_06-1.3389.hdf5
#
# Epoch 00007: val_loss did not improve from 1.33892
#
# Epoch 00008: val_loss improved from 1.33892 to 1.31600, saving model to ./model/modelMultiClassification\Network_4_08-1.3160.hdf5
#
# Epoch 00009: val_loss did not improve from 1.31600
#
# Epoch 00010: val_loss did not improve from 1.31600
#
# Epoch 00011: val_loss did not improve from 1.31600
#
# Epoch 00012: val_loss did not improve from 1.31600
#
# Epoch 00013: val_loss did not improve from 1.31600
#
# Epoch 00014: val_loss improved from 1.31600 to 1.29315, saving model to ./model/modelMultiClassification\Network_4_14-1.2931.hdf5
#
# Epoch 00015: val_loss improved from 1.29315 to 1.29212, saving model to ./model/modelMultiClassification\Network_4_15-1.2921.hdf5
#
# Epoch 00016: val_loss improved from 1.29212 to 1.27735, saving model to ./model/modelMultiClassification\Network_4_16-1.2774.hdf5
#
# Epoch 00017: val_loss did not improve from 1.27735
#
# Epoch 00018: val_loss did not improve from 1.27735
#
# Epoch 00019: val_loss did not improve from 1.27735
#
# Epoch 00020: val_loss did not improve from 1.27735
#
# Epoch 00021: val_loss did not improve from 1.27735
#
# Epoch 00022: val_loss did not improve from 1.27735
#
# Epoch 00023: val_loss did not improve from 1.27735
#
# Epoch 00024: val_loss did not improve from 1.27735
#
# Epoch 00025: val_loss did not improve from 1.27735
#
# Epoch 00026: val_loss did not improve from 1.27735
# -----------------------
# network: 4
# done for fitting
# 3/3 [==============================] - 0s 2ms/step - loss: 1.4432 - accuracy: 0.7000
# Test loss: 1.4431743621826172
# Test accuracy: 0.699999988079071
# time  2.8056893348693848
#
# Epoch 00001: val_loss improved from inf to 1.91827, saving model to ./model/modelMultiClassification\Network_5_01-1.9183.hdf5
#
# Epoch 00002: val_loss improved from 1.91827 to 1.75226, saving model to ./model/modelMultiClassification\Network_5_02-1.7523.hdf5
#
# Epoch 00003: val_loss improved from 1.75226 to 1.61168, saving model to ./model/modelMultiClassification\Network_5_03-1.6117.hdf5
#
# Epoch 00004: val_loss improved from 1.61168 to 1.50154, saving model to ./model/modelMultiClassification\Network_5_04-1.5015.hdf5
#
# Epoch 00005: val_loss improved from 1.50154 to 1.33733, saving model to ./model/modelMultiClassification\Network_5_05-1.3373.hdf5
#
# Epoch 00006: val_loss improved from 1.33733 to 1.24060, saving model to ./model/modelMultiClassification\Network_5_06-1.2406.hdf5
#
# Epoch 00007: val_loss improved from 1.24060 to 1.20677, saving model to ./model/modelMultiClassification\Network_5_07-1.2068.hdf5
#
# Epoch 00008: val_loss improved from 1.20677 to 1.15023, saving model to ./model/modelMultiClassification\Network_5_08-1.1502.hdf5
#
# Epoch 00009: val_loss improved from 1.15023 to 1.13269, saving model to ./model/modelMultiClassification\Network_5_09-1.1327.hdf5
#
# Epoch 00010: val_loss improved from 1.13269 to 1.12852, saving model to ./model/modelMultiClassification\Network_5_10-1.1285.hdf5
#
# Epoch 00011: val_loss did not improve from 1.12852
#
# Epoch 00012: val_loss improved from 1.12852 to 1.07977, saving model to ./model/modelMultiClassification\Network_5_12-1.0798.hdf5
#
# Epoch 00013: val_loss did not improve from 1.07977
#
# Epoch 00014: val_loss did not improve from 1.07977
#
# Epoch 00015: val_loss did not improve from 1.07977
#
# Epoch 00016: val_loss did not improve from 1.07977
#
# Epoch 00017: val_loss did not improve from 1.07977
#
# Epoch 00018: val_loss did not improve from 1.07977
#
# Epoch 00019: val_loss did not improve from 1.07977
#
# Epoch 00020: val_loss did not improve from 1.07977
#
# Epoch 00021: val_loss did not improve from 1.07977
#
# Epoch 00022: val_loss did not improve from 1.07977
# -----------------------
# network: 5
# done for fitting
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3338 - accuracy: 0.7000
# Test loss: 1.333836317062378
# Test accuracy: 0.699999988079071
# time  3.470089912414551
# ============================================

# %%
theModelStatic
# Out:
# [<tensorflow.python.keras.engine.sequential.Sequential at 0x1f677995e80>,
#  <tensorflow.python.keras.engine.sequential.Sequential at 0x1f677bb1760>,
#  <tensorflow.python.keras.engine.sequential.Sequential at 0x1f677ff8ac0>,
#  <tensorflow.python.keras.engine.sequential.Sequential at 0x1f677ff1d30>,
#  <tensorflow.python.keras.engine.sequential.Sequential at 0x1f67345a820>,
#  <tensorflow.python.keras.engine.sequential.Sequential at 0x1f673490940>]

# %%
for i in range(len( theModelFitHistory)):
    history = theModelFitHistory[i]
    y_vloss = history.history['val_loss'] # test loss
    y_loss = history.history['loss'] # train loss

    x_len = np.arange(len(y_loss))
    plt.plot(x_len, y_vloss, marker='.', c="red", label='Val/Testset_loss')
    plt.plot(x_len, y_loss, marker='.', c="blue", label='Trainset_loss')

    print('network:',i)
    plt.legend(loc='upper right')
    plt.grid()
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.show()
# Out:
# network: 0
# network: 1
# network: 2
# network: 3
# network: 4
# network: 5

# %%
# # for google colab
# from google.colab import drive 
# drive.mount('/content/gdrive')
# pathFileName = "gdrive/My Drive/njs-python-core/workshopPublic/SmartDrawing/data/vector/vectorData.csv"
# # df=pd.read_csv('pathFileName')
# dataSet = np.loadtxt(pathFileName, delimiter=',')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# import prepared data
dataSet = np.loadtxt( 'data/vector/vectorData.csv', delimiter=',')
np.random.seed(222)
np.random.shuffle(dataSet)
dataSet.shape
# Out:
# (530, 502)

# %%
# print dimension of data(dot product and class)
Y = dataSet[:,-1:]
X = dataSet[:,:-1]
print('dim class: ', Y.shape)
print('dim mat: ', X.shape)
# Out:
# dim class:  (530, 1)
# dim mat:  (530, 501)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=30)
X_test, X_val, Y_test, Y_val = train_test_split(X_test, Y_test, test_size=0.5, random_state=30)


Y_train = tf.keras.utils.to_categorical(Y_train)
Y_test = tf.keras.utils.to_categorical(Y_test)
Y_val = tf.keras.utils.to_categorical(Y_val)

xDim = X_train.shape[1]
yDim = Y_train.shape[1]

# %%
import time

model = Sequential()
model.add(Dense(30, input_dim=xDim, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(yDim, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam',  metrics=['accuracy'])

start_time = time.time()
hist = model.fit( 
    X_train, Y_train, validation_data=(X_test, Y_test), 
    epochs=100, batch_size=10,
    # verbose=0
    )

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Epoch 1/100
# 40/40 [==============================] - 2s 15ms/step - loss: 1.9254 - accuracy: 0.2846 - val_loss: 1.6914 - val_accuracy: 0.3939
# Epoch 2/100
# 40/40 [==============================] - 0s 6ms/step - loss: 1.4705 - accuracy: 0.4937 - val_loss: 1.3170 - val_accuracy: 0.5909
# Epoch 3/100
# 40/40 [==============================] - 0s 5ms/step - loss: 1.1601 - accuracy: 0.6625 - val_loss: 1.0422 - val_accuracy: 0.7727
# Epoch 4/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.9118 - accuracy: 0.7380 - val_loss: 0.8042 - val_accuracy: 0.8182
# Epoch 5/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7424 - accuracy: 0.8010 - val_loss: 0.6788 - val_accuracy: 0.8333
# Epoch 6/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.6290 - accuracy: 0.8161 - val_loss: 0.6357 - val_accuracy: 0.8939
# Epoch 7/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5579 - accuracy: 0.8463 - val_loss: 0.5567 - val_accuracy: 0.8485
# Epoch 8/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.4920 - accuracy: 0.8539 - val_loss: 0.5653 - val_accuracy: 0.8636
# Epoch 9/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4398 - accuracy: 0.8766 - val_loss: 0.5185 - val_accuracy: 0.8788
# Epoch 10/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3844 - accuracy: 0.8917 - val_loss: 0.5025 - val_accuracy: 0.8636
# Epoch 11/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3645 - accuracy: 0.8791 - val_loss: 0.4793 - val_accuracy: 0.8939
# Epoch 12/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3242 - accuracy: 0.8942 - val_loss: 0.4769 - val_accuracy: 0.8788
# Epoch 13/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2910 - accuracy: 0.9068 - val_loss: 0.4762 - val_accuracy: 0.9091
# Epoch 14/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2530 - accuracy: 0.9345 - val_loss: 0.4775 - val_accuracy: 0.8939
# Epoch 15/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2483 - accuracy: 0.9270 - val_loss: 0.4657 - val_accuracy: 0.8788
# Epoch 16/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2146 - accuracy: 0.9345 - val_loss: 0.4861 - val_accuracy: 0.8939
# Epoch 17/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1989 - accuracy: 0.9471 - val_loss: 0.4903 - val_accuracy: 0.8788
# Epoch 18/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1875 - accuracy: 0.9471 - val_loss: 0.4807 - val_accuracy: 0.9091
# Epoch 19/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1702 - accuracy: 0.9647 - val_loss: 0.4399 - val_accuracy: 0.8939
# Epoch 20/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1578 - accuracy: 0.9698 - val_loss: 0.4725 - val_accuracy: 0.9091
# Epoch 21/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1382 - accuracy: 0.9723 - val_loss: 0.4580 - val_accuracy: 0.9091
# Epoch 22/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.1310 - accuracy: 0.9597 - val_loss: 0.4515 - val_accuracy: 0.9091
# Epoch 23/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1235 - accuracy: 0.9748 - val_loss: 0.4589 - val_accuracy: 0.9091
# Epoch 24/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1079 - accuracy: 0.9874 - val_loss: 0.4719 - val_accuracy: 0.9091
# Epoch 25/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.1069 - accuracy: 0.9798 - val_loss: 0.4762 - val_accuracy: 0.9091
# Epoch 26/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0932 - accuracy: 0.9849 - val_loss: 0.5011 - val_accuracy: 0.8939
# Epoch 27/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0986 - accuracy: 0.9824 - val_loss: 0.5095 - val_accuracy: 0.8788
# Epoch 28/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0802 - accuracy: 0.9899 - val_loss: 0.4937 - val_accuracy: 0.9091
# Epoch 29/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0764 - accuracy: 0.9899 - val_loss: 0.5098 - val_accuracy: 0.8939
# Epoch 30/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0752 - accuracy: 0.9899 - val_loss: 0.5016 - val_accuracy: 0.8939
# Epoch 31/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0668 - accuracy: 0.9924 - val_loss: 0.5100 - val_accuracy: 0.8939
# Epoch 32/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0642 - accuracy: 0.9950 - val_loss: 0.5791 - val_accuracy: 0.8788
# Epoch 33/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0605 - accuracy: 0.9899 - val_loss: 0.5152 - val_accuracy: 0.9091
# Epoch 34/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0499 - accuracy: 0.9950 - val_loss: 0.5377 - val_accuracy: 0.9091
# Epoch 35/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0464 - accuracy: 0.9950 - val_loss: 0.5429 - val_accuracy: 0.9091
# Epoch 36/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0448 - accuracy: 0.9950 - val_loss: 0.5524 - val_accuracy: 0.8939
# Epoch 37/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0422 - accuracy: 0.9950 - val_loss: 0.5689 - val_accuracy: 0.8939
# Epoch 38/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0378 - accuracy: 0.9950 - val_loss: 0.5569 - val_accuracy: 0.8939
# Epoch 39/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0341 - accuracy: 0.9950 - val_loss: 0.5562 - val_accuracy: 0.9091
# Epoch 40/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0330 - accuracy: 0.9950 - val_loss: 0.5791 - val_accuracy: 0.9091
# Epoch 41/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0302 - accuracy: 0.9950 - val_loss: 0.5692 - val_accuracy: 0.9091
# Epoch 42/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0287 - accuracy: 0.9950 - val_loss: 0.5836 - val_accuracy: 0.9091
# Epoch 43/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0264 - accuracy: 0.9950 - val_loss: 0.5594 - val_accuracy: 0.8788
# Epoch 44/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0259 - accuracy: 0.9975 - val_loss: 0.5727 - val_accuracy: 0.9091
# Epoch 45/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0244 - accuracy: 0.9950 - val_loss: 0.5722 - val_accuracy: 0.8939
# Epoch 46/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0226 - accuracy: 0.9975 - val_loss: 0.6028 - val_accuracy: 0.9091
# Epoch 47/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0216 - accuracy: 0.9975 - val_loss: 0.5854 - val_accuracy: 0.9091
# Epoch 48/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.5946 - val_accuracy: 0.9091
# Epoch 49/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.6003 - val_accuracy: 0.8939
# Epoch 50/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.5917 - val_accuracy: 0.8939
# Epoch 51/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.6005 - val_accuracy: 0.9091
# Epoch 52/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.6179 - val_accuracy: 0.8939
# Epoch 53/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.5967 - val_accuracy: 0.9091
# Epoch 54/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.6114 - val_accuracy: 0.8939
# Epoch 55/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.6120 - val_accuracy: 0.8939
# Epoch 56/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.6213 - val_accuracy: 0.8939
# Epoch 57/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.6232 - val_accuracy: 0.8788
# Epoch 58/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.6279 - val_accuracy: 0.8939
# Epoch 59/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.6202 - val_accuracy: 0.8939
# Epoch 60/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.6295 - val_accuracy: 0.8939
# Epoch 61/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.6252 - val_accuracy: 0.8939
# Epoch 62/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.6210 - val_accuracy: 0.8939
# Epoch 63/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.6612 - val_accuracy: 0.8939
# Epoch 64/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.6323 - val_accuracy: 0.8939
# Epoch 65/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.6615 - val_accuracy: 0.8939
# Epoch 66/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.6614 - val_accuracy: 0.8939
# Epoch 67/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.6599 - val_accuracy: 0.8939
# Epoch 68/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.6624 - val_accuracy: 0.8939
# Epoch 69/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.6758 - val_accuracy: 0.8939
# Epoch 70/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.6657 - val_accuracy: 0.8939
# Epoch 71/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.6684 - val_accuracy: 0.8939
# Epoch 72/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.6859 - val_accuracy: 0.8939
# Epoch 73/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.6740 - val_accuracy: 0.8939
# Epoch 74/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.6853 - val_accuracy: 0.8939
# Epoch 75/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.6854 - val_accuracy: 0.8939
# Epoch 76/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.6919 - val_accuracy: 0.8939
# Epoch 77/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.6915 - val_accuracy: 0.8939
# Epoch 78/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.6966 - val_accuracy: 0.8939
# Epoch 79/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.7034 - val_accuracy: 0.8939
# Epoch 80/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.7006 - val_accuracy: 0.8939
# Epoch 81/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.7130 - val_accuracy: 0.8939
# Epoch 82/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.7158 - val_accuracy: 0.8939
# Epoch 83/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.7124 - val_accuracy: 0.8939
# Epoch 84/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.7190 - val_accuracy: 0.8939
# Epoch 85/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.7397 - val_accuracy: 0.8939
# Epoch 86/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.7169 - val_accuracy: 0.8939
# Epoch 87/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.7310 - val_accuracy: 0.8939
# Epoch 88/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.7262 - val_accuracy: 0.8939
# Epoch 89/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.7349 - val_accuracy: 0.8939
# Epoch 90/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.7280 - val_accuracy: 0.8939
# Epoch 91/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.7421 - val_accuracy: 0.8939
# Epoch 92/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.7464 - val_accuracy: 0.8939
# Epoch 93/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.7400 - val_accuracy: 0.8939
# Epoch 94/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.7415 - val_accuracy: 0.8939
# Epoch 95/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.7569 - val_accuracy: 0.8939
# Epoch 96/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.7524 - val_accuracy: 0.8939
# Epoch 97/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.7567 - val_accuracy: 0.8939
# Epoch 98/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.7613 - val_accuracy: 0.8939
# Epoch 99/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.7690 - val_accuracy: 0.8939
# Epoch 100/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.7650 - val_accuracy: 0.8939
# --- 20.076316833496094 seconds ---

# %%
model.evaluate(X_val, Y_val)
# Out:
# 3/3 [==============================] - 0s 2ms/step - loss: 1.0087 - accuracy: 0.8507
# [1.008734107017517, 0.8507462739944458]

# %%
model.evaluate(X_val, Y_val)
historyData = hist.history

fig = plt.figure(figsize=(10, 5))
ax0 = fig.add_subplot(1,2, 1)
ax0.set_title('Loss')
ax0.grid()
ax0.set_xlabel('Epochs')
ax0.set_ylabel('Loss')
ax0.plot(range(1,len(historyData['loss'])+1), historyData['loss'], c='red', label ='train loss' )
ax0.plot(range(1,len(historyData['val_loss'])+1), historyData['val_loss'], c='green', label ='val loss' )
ax0.legend()

ax1 = fig.add_subplot(1,2, 2)
ax1.set_title('Accuracy')
ax1.grid()
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.plot(range(1,len(historyData['accuracy'])+1), historyData['accuracy'], c='red', label ='train accuracy' )
ax1.plot(range(1,len(historyData['val_accuracy'])+1), historyData['val_accuracy'], c='green', label ='val accuracy' )
ax1.legend()
# Out:
# 3/3 [==============================] - 0s 2ms/step - loss: 1.0087 - accuracy: 0.8507

# %%
model = Sequential()
model.add(Dense(256, input_dim=xDim, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(yDim, activation='softmax'))
# binary_crossentropy
model.compile(loss='categorical_crossentropy', optimizer='adam',  metrics=['accuracy'])
hist = model.fit( 
    X_train, Y_train, validation_data=(X_test, Y_test), 
    epochs=300, batch_size=32,
    verbose=0
    )
    
model.evaluate(X_train, Y_train)
model.evaluate(X_test, Y_test)
model.evaluate(X_val, Y_val)
historyData = hist.history

fig = plt.figure(figsize=(10, 5))
ax0 = fig.add_subplot(1,2, 1)
ax0.set_title('Loss')
ax0.grid()
ax0.set_xlabel('Epochs')
ax0.set_ylabel('Loss')
ax0.plot(range(1,len(historyData['loss'])+1), historyData['loss'], c='red', label ='train loss' )
ax0.plot(range(1,len(historyData['val_loss'])+1), historyData['val_loss'], c='green', label ='val loss' )
ax0.legend()

ax1 = fig.add_subplot(1,2, 2)
ax1.set_title('Accuracy')
ax1.grid()
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.plot(range(1,len(historyData['accuracy'])+1), historyData['accuracy'], c='red', label ='train accuracy' )
ax1.plot(range(1,len(historyData['val_accuracy'])+1), historyData['val_accuracy'], c='green', label ='val accuracy' )
ax1.legend()
# Out:
# 13/13 [==============================] - 0s 2ms/step - loss: 2.5822e-05 - accuracy: 1.0000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.1952 - accuracy: 0.8636
# 3/3 [==============================] - 0s 3ms/step - loss: 0.9709 - accuracy: 0.8507

# %%
from keras.layers import Dense, Dropout

model = Sequential()
model.add(Dense(256, input_dim=xDim, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(12, activation='relu'))
model.add(Dense(yDim, activation='softmax'))
# binary_crossentropy
model.compile(loss='categorical_crossentropy', optimizer='adam',  metrics=['accuracy'])
hist = model.fit( 
    X_train, Y_train, validation_data=(X_test, Y_test), 
    epochs=300, batch_size=32,
    verbose=0
    )
    
model.evaluate(X_train, Y_train)
model.evaluate(X_test, Y_test)
model.evaluate(X_val, Y_val)
historyData = hist.history

fig = plt.figure(figsize=(10, 5))
ax0 = fig.add_subplot(1,2, 1)
ax0.set_title('Loss')
ax0.grid()
ax0.set_xlabel('Epochs')
ax0.set_ylabel('Loss')
ax0.plot(range(1,len(historyData['loss'])+1), historyData['loss'], c='red', label ='train loss' )
ax0.plot(range(1,len(historyData['val_loss'])+1), historyData['val_loss'], c='green', label ='val loss' )
ax0.legend()

ax1 = fig.add_subplot(1,2, 2)
ax1.set_title('Accuracy')
ax1.grid()
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.plot(range(1,len(historyData['accuracy'])+1), historyData['accuracy'], c='red', label ='train accuracy' )
ax1.plot(range(1,len(historyData['val_accuracy'])+1), historyData['val_accuracy'], c='green', label ='val accuracy' )
ax1.legend()
# Out:
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0545 - accuracy: 0.9849
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6932 - accuracy: 0.8788
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6449 - accuracy: 0.8060

# %% [markdown]
# ## Implementation

# %%
import math
class NVector3:
  x = 0
  y = 0
  z = 0
  def __init__(self, x = 0 , y = 0, z = 0):
    self.x = x
    self.y = y
    self.z = z
  def Noramlized(self):
    len = math.sqrt(self.x * self.x + self.y * self.y + self.z * self.z)

    if len < 0.0000001:
      return NVector3(self.x, self.y, self.z);
    
    self.x /= len
    self.y /= len
    self.z /= len

    return NVector3(self.x, self.y, self.z);

def DotProduct(v1, v2):
  return v1.x * v2.x + v1.y * v2.y + v1.z * v2.z;

def ComputeDotProducts(vs):
  out = []
  for i in range(len(vs)):
    if i < len(vs) - 1:
      v0 = NVector3(vs[i]['x'], vs[i]['y'], 0);
      v1 = NVector3(vs[i + 1]['x'], vs[i + 1]['y'], 0);

      v1.x -= v0.x;
      v1.y -= v0.y;
      v1.z -= v0.z;

      dot = DotProduct(NVector3(1, 0, 0), v1.Noramlized());
      out.append(dot);
    else:
      v0 = NVector3(vs[i]['x'], vs[i]['y'], 0);
      v1 = NVector3(vs[0]['x'], vs[0]['y'], 0);

      v1.x -= v0.x;
      v1.y -= v0.y;
      v1.z -= v0.z;

      dot = DotProduct(NVector3(1, 0, 0), v1.Noramlized());
      out.append(dot);
  return out;
def LinearInterpolate(before, after, atPoint):
  return before + (after - before) * atPoint;

def GetInterpolatedArray(data, fitCount):
  newData = [];
  springFactor = (len(data) - 1) / (fitCount - 1);
  newData.append(data[0]);
  for i in range(fitCount-1):
    tmp = i * springFactor;
    before = +(math.floor(tmp));
    after = +(math.ceil(tmp));
    atPoint = tmp - before;
    newData.append(LinearInterpolate(data[before], data[after], atPoint));
  newData[fitCount - 1] = data[len(data) - 1];
  return newData;

# %%
# from IPython.display import HTML, Image
# from google.colab.output import eval_js
# from base64 import b64decode

# canvas_html = """
# <canvas width=%d height=%d></canvas>
# <button>Finish</button>
# <script>
# let canvas = document.querySelector('canvas')
# let ctx = canvas.getContext('2d')
# ctx.lineWidth = %d
# ctx.fillStyle = '#ffffff';
# ctx.beginPath();
# ctx.rect(0, 0, ctx.canvas.width, ctx.canvas.height);
# ctx.closePath();
# ctx.fill();

# let button = document.querySelector('button')
# let mouse = {x: 0, y: 0}
# let pos = [];
# let pressed = false;



# canvas.addEventListener('mousemove', function(e) {

#   mouse.x = e.pageX - this.offsetLeft
#   mouse.y = e.pageY - this.offsetTop

#   if (!pressed) { return; }
#   console.log(mouse);
#   pos.push({x: mouse.x, y: mouse.y});
# })
# canvas.onmousedown = ()=>{
#   pressed = true;
#   ctx.beginPath()
#   ctx.moveTo(mouse.x, mouse.y)
#   canvas.addEventListener('mousemove', onPaint)
# }
# canvas.onmouseup = ()=>{
#   pressed = false;
#   canvas.removeEventListener('mousemove', onPaint)
# }
# let onPaint = ()=>{
#   ctx.lineTo(mouse.x, mouse.y)
#   ctx.stroke()
# }
# let data = new Promise(resolve=>{
#   button.onclick = ()=>{
#     resolve(canvas.toDataURL('image/png'))
#   }
# })
# </script>
# """


# def draw(filename='drawing.png', w=400, h=200, line_width=4):
#   display(HTML(canvas_html % (w, h, line_width)))
#   data = eval_js("data")

#   dataFromCanvas = eval_js("pos")

#   binary = b64decode(data.split(',')[1])
#   with open(filename, 'wb') as f:
#     f.write(binary)
#   print('done!! ',len(binary))
#   return eval_js("pos")

# %%
# dataFromCanvas = draw()

# data = dataFromCanvas
# # for i in range(len(data)):
#   # print (i)
#   # print(data[i]['x'], data[i]['y'])

# dotList = ComputeDotProducts(data);
# dotListReMap = GetInterpolatedArray(dotList, 501)

# print(len(dotListReMap))
# theDotList = np.matrix(dotListReMap)

# resultClass = {
#    0: "circle",
#    1: "try-gon",
#    2: "arrow",
#    3: "arrowDouble",
#    4: "rect",
#    5: "text",
#    6: "curve",
#    7: "heart",
#    8: "cloud",
# }

# result = model.predict(theDotList);
# print(result)
# print(model.name, resultClass[np.argmax(result)])

# %% [markdown]
# Link for testing https://namjulee.github.io/njs-lab-public/lab/machine-learning/tf-smart-drawing

# %%
# https://www.tensorflow.org/js/tutorials/conversion/import_keras
# !pip install tensorflowjs
# Out:
# Collecting tensorflowjs
#   Downloading tensorflowjs-3.17.0-py3-none-any.whl (77 kB)
# Requirement already satisfied: six<2,>=1.12.0 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorflowjs) (1.15.0)
# Collecting tensorflow-hub<0.13,>=0.7.0
#   Using cached tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
# Requirement already satisfied: tensorflow<3,>=2.1.0 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorflowjs) (2.5.2)
# Collecting packaging~=20.9
#   Using cached packaging-20.9-py2.py3-none-any.whl (40 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from packaging~=20.9->tensorflowjs) (3.0.6)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.0)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.19.5)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.12.1)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.3.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.2)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.7.4.3)
# Requirement already satisfied: tensorboard~=2.5 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.6.0)
# Requirement already satisfied: wheel~=0.35 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.35.1)
# Requirement already satisfied: grpcio~=1.34.0 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.34.1)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.5.0.dev2021032900)
# Requirement already satisfied: absl-py~=0.10 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.12.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.12)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.5.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.17.2)
# Requirement already satisfied: gast==0.4.0 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.4.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.35.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (60.1.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.6.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2.26.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2.0.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.2.7)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (4.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2.0.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\namju\miniconda3\envs\tf-gpu-2021\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.1.1)
# Installing collected packages: tensorflow-hub, packaging, tensorflowjs
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
# Successfully installed packaging-20.9 tensorflow-hub-0.12.0 tensorflowjs-3.17.0

# %%
import tensorflowjs as tfjs

# %%
# path = '../../../../../../Users/namj9345/Desktop/dt-sandbox/public/fake-data/ngraphics/ML/SmartDrawing/modelMultiClassification/'
path = 'model/modeljs'
tfjs.converters.save_keras_model(theModelStatic[5], path)

# %% [markdown]
# ### [Colab version](https://colab.research.google.com/drive/1LOP36_Z46P4rJ5D2D5lE4P1OMDgOzMUJ#scrollTo=X2XXbVGI4Zwf)
