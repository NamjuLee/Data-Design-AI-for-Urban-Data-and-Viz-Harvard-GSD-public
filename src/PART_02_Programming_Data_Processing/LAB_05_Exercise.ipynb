# %% [markdown]
# # **Data in Design, AI for Urban Data and Visualization**
#
# #### Data, Design Computation, Artificial Intelligence, Visualization, Harvard GSD J Term 2023
#
#
# **KEYWORD:**
# Vector, Raster, Urban Data, GIS, Data Processing, Data Science, Design Science, Data Mining, Machine Learning, Artificial Intelligence, Visualization, Mapping, Design Decision-Making
#
# -----
#
# #### Instructor : NJ Namju Lee / nj.namju@gmail.com
# ###### * Linkedin - https://www.linkedin.com/in/nj-namju-lee-926b3252/    * Git - https://github.com/NamjuLee
#
# ###### * Web - http://www.njstudio.co.kr                                  * Lab - http://www.njslab.com/NJSLabCore/
#
# ###### * Video(English) - https://www.youtube.com/c/njnamjulee            * Writing(English) - https://medium.com/@nj-namju
#
# ###### * Video(Korean) - https://www.youtube.com/c/CodeforDesign          * Writing(Korean) - https://brunch.co.kr/@njnamju
# -----

# %% [markdown]
# # Homework

# %% [markdown]
# 1. Domain & Interval

# %%
S = 1
E = 10
N = 5

interval = (E - S) / ( N - 1)

for i in range(N):
    print( S + i * interval )
# Out:
# 1.0
# 3.25
# 5.5
# 7.75
# 10.0

# %%
# your code here

# %% [markdown]
# 2. Series

# %%
S = 1
N = 10
C = 4

outList = [];
for i in range(C):
    result = S + ( i * N  )
    outList.append(result);

a = outList
print(a)
# Out:
# [1, 11, 21, 31]

# %%
# your code here

# %% [markdown]
# 3. Remap

# %%
V = 8
sMin = 0.0
sMax = 10.00
tMin = 0
tMax = 51.4

result  = (((V - sMin) * (tMax - tMin)) / (sMax - sMin)) + tMin;
print(result)
# Out:
# 41.12

# %%
# your code here

# %% [markdown]
# 3 item

# %%
i = 10
L = ['a', 'b', 'c', 'd', 1, 2, 3, 4];
W = True;

if W == True:
    print(L[int(i % len(L))]);
else :
    try:
        print(L[i])
    except:
        print('out of range');
# Out:
# c

# %% [markdown]
# 4. Split strings

# %%
T = "1, 2, 3, a, b, c"
outList = []
for i in T.split(","):
    outList.append(i)

a = outList
print(a)
# Out:
# ['1', ' 2', ' 3', ' a', ' b', ' c']

# %%
# your code here

# %% [markdown]
# 5. Reverse String data

# %%
newTextArray = []
txt = 'helloWorld'
textOut = ''

for i in txt:
  newTextArray.append(i)

for i in range( int(len(newTextArray) / 2)):
  temp = newTextArray[i]
  newTextArray[i] = newTextArray[len(newTextArray) - i - 1]
  newTextArray[len(newTextArray) - i - 1] = temp

for i in newTextArray:
  textOut+= i

print(textOut)
# Out:
# dlroWolleh

# %%
txt = 'helloWorld'
txtReverse = txt[::-1]
print(txtReverse)
# Out:
# dlroWolleh

# %%
# your code here

# %%
import math
# a possible answer
def getMin(data):
    theMin = data[0]
    for i in data:
        if theMin > i:
            theMin = i
    return theMin
def getMax(data):
    theMin = data[0]
    for i in data:
        if theMin < i:
            theMin = i
    return theMin
def getMean(data):
    theSum = 0.0;
    for i in data:
        theSum+=i
    return theSum / len(data)
def getMedian(data):
    data.sort()
    theIndex = len(data) / 2
    if theIndex % 2 == 0:
        return data[theIndex]
    else:
        return (data[theIndex-1] + data[theIndex]) / 2.0

data = [2,5,7,2,1,10,12,45,62,23,53,12,3,6,7]
print ("the min:", getMin(data))
print ("the max:", getMax(data))
print ("the mean:", getMean(data))
print ("the median:", getMedian(data))
# Out:
# the min: 1
# the max: 62
# the mean: 16.666666666666668
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\njz\njsCore\workshop\Data-Design-AI-for-Urban-Data-and-Viz-Harvard-GSD-public\src\PART_02_Programming_Data_Processing\LAB_05_Exercise.ipynb Cell 21 in <cell line: 32>()
#      <a href='vscode-notebook-cell:/c%3A/njz/njsCore/workshop/Data-Design-AI-for-Urban-Data-and-Viz-Harvard-GSD-public/src/PART_02_Programming_Data_Processing/LAB_05_Exercise.ipynb#X30sZmlsZQ%3D%3D?line=29'>30</a> print ("the max:", getMax(data))
#      <a href='vscode-notebook-cell:/c%3A/njz/njsCore/workshop/Data-Design-AI-for-Urban-Data-and-Viz-Harvard-GSD-public/src/PART_02_Programming_Data_Processing/LAB_05_Exercise.ipynb#X30sZmlsZQ%3D%3D?line=30'>31</a> print ("the mean:", getMean(data))
# ...

# %%
# your code here

# %% [markdown]
# ## Additional Reading and Resources
#
# #### python documentation(3.x)
# https://docs.python.org/3/
#
# #### codecademy
# https://www.codecademy.com/learn/learn-python-3
#
# ### Think Python
# https://www.greenteapress.com/thinkpython/thinkpython.pdf

# %% [markdown]
# ---
#
# ## Numpy:
#
# https://www.w3schools.com/python/numpy/default.asp
#
# https://www.kaggle.com/code/orhansertkaya/numpy-tutorial-for-beginners
#
# https://www.kaggle.com/code/lavanyashukla01/pandas-numpy-python-cheatsheet

# %% [markdown]
# ---
#
# ## Pandas:
#
# https://www.w3schools.com/python/pandas/default.asp
#
# https://www.kaggle.com/code/kralmachine/pandas-tutorial-for-beginners
#
#
#
# https://www.kaggle.com/code/lavanyashukla01/pandas-numpy-python-cheatsheet

# %% [markdown]
# ---
#
# ## Data Science
#
# https://www.w3schools.com/datascience/
#
#
# https://www.kaggle.com/code/kanncaa1/data-sciencetutorial-for-beginners
